# %% [markdown]
# <a href="https://colab.research.google.com/github/KaimwenK/MKT-440-of-Wen/blob/main/Final_Assignment_of_Wen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
url = "https://raw.githubusercontent.com/KaimwenK/MKT-440-of-Wen/main/Chipotle.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#             top1 wordofmouth socialmedia walkby billboard  patronage  \
# 0      Applebees         Yes          No     No        No          0
# 1          Arbys         Yes          No     No        No          0
# 2          Arbys          No          No    Yes        No          0
# 3          Arbys          No          No     No        No          0
# 4    Burger King          No         Yes     No        No          0
# ..           ...         ...         ...    ...       ...        ...
# 352       Subway         Yes          No     No        No          0
# 353    Taco Bell         Yes          No     No        No          0
# 354   The Market         Yes          No     No        No          0
# 355      Wendy's         Yes          No     No        No          0
# 356      Wendy's         Yes          No     No        No          0
#
#      importantconvenience  importantvariety  importantprice  importanthealthy  \
# ...

# %%
# Select the continuous variables
cont_vars = df.select_dtypes(include=["float64", "int64"])

# %%
# Descriptive stats for the continuous variables
cont_vars.describe()
# Out:
#         patronage  importantconvenience  importantvariety  importantprice  \
# count  357.000000            338.000000        333.000000      334.000000
# mean     0.487395              4.500000          4.312312        4.670659
# std      1.128280              0.659332          0.688808        0.589631
# min      0.000000              1.000000          1.000000        2.000000
# 25%      0.000000              4.000000          4.000000        4.000000
# 50%      0.000000              5.000000          4.000000        5.000000
# 75%      0.000000              5.000000          5.000000        5.000000
# max      6.000000              5.000000          5.000000        5.000000
#
#        importanthealthy  importanttaste  importantambience  \
# count        335.000000      332.000000         335.000000
# mean           4.534328        4.927711           4.232836
# std            0.668709        0.259357           0.660790
# min            2.000000        4.000000           1.000000
# ...

# %%
# pairplot of the continuous variables
sns.pairplot(cont_vars)

# %%
#correlation matrix
corr = cont_vars.corr()

# %%
# heatmap of the correlation matrix
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)

# %%
# select the categorical variables
categorical = df.select_dtypes(include=["object"])

# %%
categorical
# Out:
#             top1 wordofmouth socialmedia walkby billboard  gender
# 0      Applebees         Yes          No     No        No    Male
# 1          Arbys         Yes          No     No        No    Male
# 2          Arbys          No          No    Yes        No  Female
# 3          Arbys          No          No     No        No  Female
# 4    Burger King          No         Yes     No        No    Male
# ..           ...         ...         ...    ...       ...     ...
# 352       Subway         Yes          No     No        No    Male
# 353    Taco Bell         Yes          No     No        No    Male
# 354   The Market         Yes          No     No        No    Male
# 355      Wendy's         Yes          No     No        No  Female
# 356      Wendy's         Yes          No     No        No    Male
#
# [357 rows x 6 columns]

# %%
# Use seaborn to create a countplot for each categorical variable
import matplotlib.pyplot as plt
fig, ax =plt.subplots(2,3)
for col in categorical:
    sns.countplot(x=col, data=df)
fig.show()

# %%
#include only the importance-related variables for the heatmap
#select the importance-related variables
importance = df.iloc[:, 7:12]

# %%
#correlation matrix
corr = importance.corr()

# %%
#create a heatmap of the correlation matrix
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)

# %%
#Create one scatterplot with age as X-axis and income as Y axis, gender as hue, using seaborn library
sns.scatterplot(x="age", y="income", hue="gender", data=df)

# %%
#add at least two more visual/stats that can provide useful insights for the Chipotle management with ease
# Calculate the number of unique values for each column
num_uniques = df.nunique()
num_uniques
# Out:
# top1                     20
# wordofmouth               2
# socialmedia               2
# walkby                    2
# billboard                 2
# patronage                 7
# importantconvenience      5
# importantvariety          5
# importantprice            4
# importanthealthy          4
# importanttaste            2
# importantambience         5
# chipotleconvenient        6
# chipotlevariety           4
# chipotleprice             6
# chipotlehealthy           5
# chipotletaste             4
# chipotleambience          4
# gender                    2
# age                      47
# income                  194
# plan                      4
# spending                  5
# buylocal                  5
# healthyimportanttome      5
# dtype: int64

# %%
# Calculate the mean value for each column
means = df.mean()
means
# Out:
# <ipython-input-16-5fa0b5262686>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   means = df.mean()
# patronage                   0.487395
# importantconvenience        4.500000
# importantvariety            4.312312
# importantprice              4.670659
# importanthealthy            4.534328
# importanttaste              4.927711
# importantambience           4.232836
# chipotleconvenient          3.763473
# chipotlevariety             3.792793
# chipotleprice               3.541667
# chipotlehealthy             4.436364
# chipotletaste               4.362275
# chipotleambience            3.759760
# age                        40.212828
# income                  40628.755102
# plan                        1.833819
# spending                    2.941349
# buylocal                    1.829412
# ...
